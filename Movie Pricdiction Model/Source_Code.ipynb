# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
#plotting our dataSet
x = DataFrame(data, columns= ['production_budget_usd'])
y = DataFrame(data, columns= ['worldwide_gross_usd'])

# %%
plt.figure(figsize = (10,7))
plt.scatter(x, y, alpha = 0.3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %%
#run and evaluate the algorithm
regression = LinearRegression()
regression.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coefficient:

# %%
regression.coef_ #theta_1
# Out:
# array([[3.11150918]])

# %% [markdown]
# Intercept Coefficient:

# %%
regression.intercept_
# Out:
# array([-7236192.72913963])

# %% [markdown]
# Plot the line

# %%
plt.figure(figsize = (10,7))
plt.scatter(x, y, alpha = 0.3)
plt.plot(x,regression.predict(x), color = 'red', linewidth = 3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# Evaluating and Analysing the performance of our model:

# %%
#theta_0 = -7236192.7 
#theta_1 = 3.1115
#h_tetha(x) = -7236192.7 + 3.1115x

# %% [markdown]
# Predict revenue for a film with a $50 million budget :
# (revenue = -7236192.7 + 3.1115*50000000 = 148333807)

# %%
#measuring the performance using R^2 method :

regression.score(x,y)
# Out:
# 0.5496485356985727
